# %% [markdown]
# Attempt to check if tracker is really a new object detection. custom tracker based on some ds data exploration.
#
# clustering problem over a time series. check avg speed and movement

# %%
import csv
import pandas as pd

df = pd.read_csv('./dataset/detections-1.csv')

print(df.shape)
print(df.head)

# with open('./dataset/detections-1.csv', 'r') as f:
#     reader = csv.reader(f)

#     for row in reader:
